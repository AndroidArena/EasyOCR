# %%
import easyocr

# %%
#download the model
reader = easyocr.Reader(['en'], gpu = False)
# Out:
# Using CPU. Note: This module is much faster with a GPU.

# %%
# show an image
import PIL
from PIL import ImageDraw
im = PIL.Image.open("invoice1.png")
#im = PIL.Image.open("france.jfif")

im
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=820x531 at 0x1EA4707B5F8>

# %%
# Doing OCR. Get bounding boxes.
bounds = reader.readtext('invoice1.png')
bounds
# Out:
# [([[52, 71], [324, 71], [324, 104], [52, 104]],
#   'COMPANY NAME',
#   0.36122334003448486),
#  ([[593, 97], [675, 97], [675, 111], [593, 111]],
#   'Street Address',
#   0.4596695601940155),
#  ([[593, 111], [695, 111], [695, 127], [593, 127]],
#   'Citj, ST ZIP Code',
#   0.19944354891777039),
#  ([[591, 129], [629, 129], [629, 143], [591, 143]],
#   'Email',
#   0.8885388374328613),
#  ([[593, 145], [651, 145], [651, 159], [593, 159]],
#   'Phone Na.',
#   0.29962095618247986),
#  ([[50, 162], [174, 162], [174, 188], [50, 188]],
#   'customer:',
#   0.7540062069892883),
#  ([[591, 171], [639, 171], [639, 185], [591, 185]],
#   'MATIo.',
#   0.2151806801557541),
#  ([[49, 193], [85, 193], [85, 207], [49, 207]], 'Name', 0.4760741591453552),
#  ([[51, 209], [133, 209], [133, 223], [51, 223]],
#   'Street Address',
#   0.5513603091239929),
#  ([[591, 209], [655, 209], [655, 223], [591, 223]],
#   'Inyoice Io',
#   0.12354633212089539),
#  ([[51, 223], [153, 223], [153, 239], [51, 239]],
#   'Citj, ST ZIP Code',
#   0.1426609456539154),
#  ([[591, 225], [671, 225], [671, 239], [591, 239]],
#   'Inyoice Date:',
#   0.15965065360069275),
#  ([[51, 243], [89, 243], [89, 259], [51, 259]], 'E mail', 0.6369486451148987),
#  ([[587, 243], [723, 243], [723, 259], [587, 259]],
#   'Payment Tems 30 Days',
#   0.02265792340040207),
#  ([[51, 259], [107, 259], [107, 275], [51, 275]],
#   'Phone No',
#   0.514975905418396),
#  ([[432, 280], [732, 280], [732, 312], [432, 312]],
#   'Commission Invoice',
#   0.8380829691886902),
#  ([[277, 341], [343, 341], [343, 355], [277, 355]],
#   'Price lgut',
#   0.14273236691951752),
#  ([[363, 341], [419, 341], [419, 355], [363, 355]],
#   'Price with',
#   0.21088138222694397),
#  ([[439, 341], [503, 341], [503, 355], [439, 355]],
#   'Total out',
#   0.08364076912403107),
#  ([[523, 341], [577, 341], [577, 355], [523, 355]],
#   'Tatal iith',
#   0.06489323079586029),
#  ([[599, 341], [669, 341], [669, 355], [599, 355]],
#   'Commissian',
#   0.366951584815979),
#  ([[51, 349], [79, 349], [79, 363], [51, 363]], 'Date', 0.8695289492607117),
#  ([[97, 349], [161, 349], [161, 365], [97, 365]],
#   'Description',
#   0.9351868033409119),
#  ([[189, 349], [211, 349], [211, 363], [189, 363]], 'aty', 0.5821679830551147),
#  ([[685, 349], [755, 349], [755, 363], [685, 363]],
#   'Net Amgunt',
#   0.2239948958158493),
#  ([[275, 357], [343, 357], [343, 371], [275, 371]],
#   'commissian',
#   0.40111568570137024),
#  ([[357, 357], [425, 357], [425, 371], [357, 371]],
#   'commissian',
#   0.4271548390388489),
#  ([[437, 357], [503, 357], [503, 371], [437, 371]],
#   'cammission',
#   0.50832599401474),
#  ([[517, 357], [585, 357], [585, 371], [517, 371]],
#   'cammissian',
#   0.6366720199584961),
#  ([[611, 357], [657, 357], [657, 371], [611, 371]],
#   'Amaunt',
#   0.1828412562608719),
#  ([[49, 385], [89, 385], [89, 399], [49, 399]], '10.6.04', 0.6867178082466125),
#  ([[97, 385], [173, 385], [173, 401], [97, 401]],
#   'Case ofsoda',
#   0.5281081199645996),
#  ([[189, 385], [211, 385], [211, 401], [189, 401]],
#   '100',
#   0.41390612721443176),
#  ([[233, 385], [255, 385], [255, 401], [233, 401]], '5.0', 0.8797406554222107),
#  ([[311, 385], [345, 385], [345, 401], [311, 401]],
#   '50.00',
#   0.5742812156677246),
#  ([[393, 385], [425, 385], [425, 401], [393, 401]],
#   '52.50',
#   0.9192739725112915),
#  ([[453, 385], [505, 385], [505, 401], [453, 401]],
#   '5,000.00',
#   0.34296903014183044),
#  ([[537, 385], [587, 385], [587, 401], [537, 401]],
#   '5,250.00',
#   0.6394738554954529),
#  ([[629, 385], [671, 385], [671, 401], [629, 401]],
#   '250.00',
#   0.5577220320701599),
#  ([[707, 385], [757, 385], [757, 401], [707, 401]],
#   '5,000.00',
#   0.3970021605491638),
#  ([[231, 411], [257, 411], [257, 427], [231, 427]],
#   '10.0',
#   0.6907672882080078),
#  ([[305, 411], [345, 411], [345, 427], [305, 427]],
#   '1o0.00',
#   0.08344478905200958),
#  ([[393, 411], [425, 411], [425, 427], [393, 427]],
#   '0.00',
#   0.22563765943050385),
#  ([[545, 411], [587, 411], [587, 427], [545, 427]],
#   '5u0.00',
#   0.2643260657787323),
#  ([[629, 411], [671, 411], [671, 427], [629, 427]],
#   '5u0.00',
#   0.17143455147743225),
#  ([[707, 411], [757, 411], [757, 427], [707, 427]],
#   '5,000.00',
#   0.3970021605491638),
#  ([[193, 413], [209, 413], [209, 427], [193, 427]], '5u', 0.2813960313796997),
#  ([[453, 413], [505, 413], [505, 427], [453, 427]],
#   '5,uu0.00',
#   0.01534971222281456)]

# %%
# Draw bounding boxes
def draw_boxes(image, bounds, color='yellow', width=2):
    draw = ImageDraw.Draw(image)
    for bound in bounds:
        p0, p1, p2, p3 = bound[0]
        draw.line([*p0, *p1, *p2, *p3, *p0], fill=color, width=width)
    return image

draw_boxes(im, bounds)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=820x531 at 0x1EA4707B5F8>

# %%
len(bounds)
# Out:
# 48

# %%
for i in bounds:
    print(i[1])
# Out:
# COMPANY NAME
# Street Address
# Citj, ST ZIP Code
# Email
# Phone Na.
# customer:
# MATIo.
# Name
# Street Address
# Inyoice Io
# Citj, ST ZIP Code
# Inyoice Date:
# E mail
# Payment Tems 30 Days
# Phone No
# Commission Invoice
# Price lgut
# Price with
# Total out
# Tatal iith
# Commissian
# Date
# Description
# aty
# Net Amgunt
# commissian
# commissian
# cammission
# cammissian
# Amaunt
# 10.6.04
# Case ofsoda
# 100
# 5.0
# 50.00
# 52.50
# 5,000.00
# 5,250.00
# 250.00
# 5,000.00
# 10.0
# 1o0.00
# 0.00
# 5u0.00
# 5u0.00
# 5,000.00
# 5u
# 5,uu0.00
